# %%
# from extract import Extractor
import pandas as pd
pd.set_option('display.max_columns', None)
from data_extraction import DataExtractor
from data_cleaning import DataCleaner

data_extractor = DataExtractor()
df_apple, df_other = data_extractor.process_itunes_tracks()

data_cleaner = DataCleaner()
df_combined = data_cleaner.clean_itunes_data(df_apple, df_other)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3573 entries, 0 to 3088
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   track                  3564 non-null   object
#  1   name                   3549 non-null   object
#  2   artist                 3556 non-null   object
#  3   release_date           3492 non-null   object
#  4   album                  3539 non-null   object
#  5   Content ID             1354 non-null   object
#  6   artist_id              1339 non-null   object
#  7   playlist_id            1354 non-null   object
#  8   genre_id               1339 non-null   object
#  9   composer_id            1083 non-null   object
#  10  xid                    1187 non-null   object
#  11  itunes_stores_country  1303 non-null   object
#  12  part_of_compilation    3080 non-null   object
#  13  composer               2449 non-null   object
#  14  disk                   3079 non-null   object
#  15  genre_type             1827 non-null   object
#  16  album_artist           2512 non-null   object
#  17  genre                  1236 non-null   object
#  18  isrc                   1187 non-null   object
# dtypes: object(19)
# memory usage: 558.3+ KB

# %%
# def _get_isrc(xid) -> str:
#     try:
#         return xid.split(":")[-1]
#     except AttributeError:
#         return ''
    
# new = df_combined.loc[:, "xid"].apply(_get_isrc)


# df_combined.head(50)
# df_combined[df_combined["isrc"].isna()]
# try: 
#     new = df_combined.loc[:, "xid"].apply(lambda x: x.split(":")[2])
# except AttributeError:
#             df.loc[:, "isrc"] = np.nan

# %%
df_combined.head(5)
# Out:
#   track                              name      artist          release_date  \
# 0     1  Tender Love (feat. Ocie Elliott)    Mounika.  2020-05-15T07:00:00Z
# 1     1               Dance With Somebody  Mando Diao  2009-01-01T08:00:00Z
# 2     1       Never Seen the Light of Day  Mando Diao  2007-10-22T07:00:00Z
# 3     1                              Slow    Leoniden  2018-10-26T07:00:00Z
# 4     1                            Moving   Kate Bush  1978-02-17T12:00:00Z
#
#                            album  Content ID   artist_id playlist_id genre_id  \
# 0                   I Need Space  1506236988  1349463293  1506236704        7
# 1  Give Me Fire (Deluxe Version)  1444159397    23533743  1444159393       21
# 2    Never Seen the Light of Day   693238755    23533743   693238753       14
# 3                          Again  1400193243   890490445  1400192916       21
# 4                    Kick Inside   726230336      487277   726230233     1133
#
#   composer_id                          xid itunes_stores_country  \
# 0  1180123828    Orchard:isrc:FR9W11928842        United Kingdom
# 1   193502097  Universal:isrc:SEYBD0800402        United Kingdom
# 2   193502097     Warner:isrc:SEAMA0700401        United Kingdom
# 3   890490445  umgglobal:isrc:DEUM71802554        United Kingdom
# 4      487277     Warner:isrc:GBAYE7800103        United Kingdom
#
#   part_of_compilation composer disk genre_type album_artist genre  \
# 0                 NaN      NaN  NaN        NaN          NaN   NaN
# 1                 NaN      NaN  NaN        NaN          NaN   NaN
# 2                 NaN      NaN  NaN        NaN          NaN   NaN
# 3                 NaN      NaN  NaN        NaN          NaN   NaN
# 4                 NaN      NaN  NaN        NaN          NaN   NaN
#
#            isrc
# 0  FR9W11928842
# 1  SEYBD0800402
# 2  SEAMA0700401
# 3  DEUM71802554
# 4  GBAYE7800103
