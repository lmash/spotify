# %%
from credentials import spotify_get, spotify_post
from data_loading import DataLoader
from data_extraction import DataExtractor
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from data_cleaning import DataCleaner
from data_linking import DataLinker

data_extractor = DataExtractor()
data_cleaner = DataCleaner()
data_linker = DataLinker(spotify=spotify_get())
data_loader = DataLoader(spotify=spotify_post())

df = data_extractor.read_pickle("combined")
# df_playlist = data_extractor.read_playlist('Enjoy the Ride.txt')
# df_playlist = data_cleaner.clean_itunes_playlist(df_playlist)
# df_playlist = data_linker.extract_all_isrc_with_na(df_playlist)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   track_name                 118 non-null    object
#  1   artist                     118 non-null    object
#  2   release_date               118 non-null    object
#  3   album                      118 non-null    object
#  4   track_number               118 non-null    object
#  5   content_id                 19 non-null     object
#  6   artist_id                  19 non-null     object
#  7   playlist_id                19 non-null     object
#  8   genre_id                   19 non-null     object
#  9   composer_id                19 non-null     object
#  10  itunes_stores_country      19 non-null     object
#  11  composer                   108 non-null    object
#  12  disk                       109 non-null    object
# ...

# %%
# df.info()
# df[~df['release_date'].isna()]

# df[df["isrc"].isna()]
# df[( 
#     (df["album"].str.contains('EP')) & (df["isrc"].isna())
#     )]

# df[df["album"] ==  "Coco Part 1"]
# df[df["Content ID"] == "1485137457"]

# df[df['album'].isna()]
# df[["track_name", "artist", "album", "spotify_track_uri", "spotify_artist_uri", "spotify_album_uri", "spotify_release_year"]]
# albums = df.groupby(by="album").count()
# albums.first()

# track_count = df.groupby(by="album")["track_name"].count()
# df_track_count = pd.DataFrame(track_count)
# df_track_count.rename(columns={'track_name': 'library_total_tracks'})
# df = df.set_index('album')

# df.head()
# df_track_count.head()

# df_merged = df.merge(df_track_count, on='album', how='left')

df_merged
# Out:
#                                                        track_name_x  \
# album
# Guilty                                                Never Give Up
# Guilty                                                Woman In Love
# Guilty                                                     Promises
# Guilty                                                   Life Story
# Guilty                                        Make It Like a Memory
# Guilty                     What Kind of Fool (Duet With Barry Gibb)
# Guilty                                                  Love Inside
# Guilty                                Guilty (Duet With Barry Gibb)
# Guilty                                                     Run Wild
# Love 2                                               Sing Sang Sung
# Love 2                                                         Love
# Love 2                                             Tropical Disease
# The Virgin Suicides                                   Dark Messages
# ...
