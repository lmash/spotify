# %%
from data_loading import DataLoader
from data_extraction import DataExtractor
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from data_cleaning import DataCleaner
from data_linking import DataLinker

data_extractor = DataExtractor()
data_cleaner = DataCleaner()
data_loader = DataLoader()
data_linker = DataLinker()

df_playlist = data_extractor.read_playlist('Enjoy the Ride.txt')
df_playlist = data_cleaner.clean_itunes_playlist(df_playlist)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'track_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/mashie/src/spotify_isrc/investigate.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/mashie/src/spotify_isrc/investigate.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> data_linker = DataLinker()
#      <a href='vscode-notebook-cell:/Users/mashie/src/spotify_isrc/investigate.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> df_playlist = data_extractor.read_playlist('Enjoy the Ride.txt')
# ---> <a href='vscode-notebook-cell:/Users/mashie/src/spotify_isrc/investigate.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> df_playlist = data_cleaner.clean_itunes_playlist(df_playlist)
#
# File ~/src/spotify_isrc/data_cleaning.py:266, in DataCleaner.clean_itunes_playlist(self, df)
#     265 def clean_itunes_playlist(self, df) -> pd.DataFrame:
# --> 266     df = self._create_spotify_columns_for_playlist(df)
#     267     df = self._drop_columns(df, config.playlist_columns_to_drop)
#     268     df = self._rename_columns(df, columns=config.playlist_columns)
#
# File ~/src/spotify_isrc/data_cleaning.py:116, in DataCleaner._create_spotify_columns_for_playlist(df)
#     113 @staticmethod
#     114 def _create_spotify_columns_for_playlist(df: pd.DataFrame) -> pd.DataFrame:
#     115     """Create new columns for searching spotify."""
# --> 116     df.loc[:, "spotify_search_track_name"] = df.loc[:, "track_name"]
#     117     df.loc[:, "spotify_search_artist"] = df.loc[:, "artist"]
#     118     return df
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexing.py:1330, in _LocIndexer._getitem_tuple(self, tup)
#    1328 with suppress(IndexingError):
#    1329     tup = self._expand_ellipsis(tup)
# -> 1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
#    1333 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexing.py:1039, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1035 for i, key in enumerate(tup):
#    1036     if is_label_like(key):
#    1037         # We don't need to check for tuples here because those are
#    1038         #  caught by the _is_nested_tuple_indexer check above.
# -> 1039         section = self._getitem_axis(key, axis=i)
#    1041         # We should never have a scalar section here, because
#    1042         #  _getitem_lowerdim is only called after a check for
#    1043         #  is_scalar_access, which that would be.
#    1044         if section.ndim == self.ndim:
#    1045             # we're in the middle of slicing through a MultiIndex
#    1046             # revise the key wrt to `section` by inserting an _NS
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/generic.py:4222, in NDFrame.xs(self, key, axis, level, drop_level)
#    4220 if axis == 1:
#    4221     if drop_level:
# -> 4222         return self[key]
#    4223     index = self.columns
#    4224 else:
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /usr/local/Caskroom/miniconda/base/envs/spotify/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'track_name'

# %%
df_playlist.head()
# Out:
#                   playlist_track_name playlist_artist  \
# 0  Enjoy the Ride (feat. Judie Tzuke)       Morcheeba
# 1                             Futures          Zero 7
# 2              I Love To Move In Here            Moby
# 3                                Hurt    Parov Stelar
# 4                    Royksopp Forever        Röyksopp
#
#           playlist_composer playlist_album     playlist_genre  playlist_disk  \
# 0                 Morcheeba      Dive Deep                Pop              1
# 1  Henry Binns/Sam Hardaker     The Garden  Electronica/Dance              1
# 2     Moby, Grandmaster Kaz     Last Night  Electronica/Dance              1
# 3            Marcus Füreder    Coco Part 1        Electronica              1
# 4                  Röyksopp         Junior         Electronic              1
#
#    playlist_track_number  playlist_release_date   playlist_name
# 0                      1                   2008  Enjoy the Ride
# 1                      1                   2006  Enjoy the Ride
# 2                      2                   2008  Enjoy the Ride
# 3                      2                   2009  Enjoy the Ride
# 4                      5                   2009  Enjoy the Ride
