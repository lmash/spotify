# %%
from data_loading import DataLoader
from data_extraction import DataExtractor
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from data_cleaning import DataCleaner
from data_linking import DataLinker

data_extractor = DataExtractor()
data_cleaner = DataCleaner()
data_loader = DataLoader()
data_linker = DataLinker()

df = data_loader.read_pickle("combined_backup")
# df_playlist = data_extractor.read_playlist('Enjoy the Ride.txt')
# df_playlist = data_cleaner.clean_itunes_playlist(df_playlist)

# %%
df_playlist.head()
# Out:
#                            track_name        artist                  composer  \
# 0  Enjoy the Ride (feat. Judie Tzuke)     Morcheeba                 Morcheeba
# 1                             Futures        Zero 7  Henry Binns/Sam Hardaker
# 2              I Love To Move In Here          Moby     Moby, Grandmaster Kaz
# 3                                Hurt  Parov Stelar            Marcus Füreder
# 4                    Royksopp Forever      Röyksopp                  Röyksopp
#
#          album              genre  disk  track_number  release_date  \
# 0    Dive Deep                Pop     1             1          2008
# 1   The Garden  Electronica/Dance     1             1          2006
# 2   Last Night  Electronica/Dance     1             2          2008
# 3  Coco Part 1        Electronica     1             2          2009
# 4       Junior         Electronic     1             5          2009
#
#     playlist_name           spotify_search_track_name spotify_search_artist
# 0  Enjoy the Ride  Enjoy the Ride (feat. Judie Tzuke)             Morcheeba
# 1  Enjoy the Ride                             Futures                Zero 7
# 2  Enjoy the Ride              I Love To Move In Here                  Moby
# 3  Enjoy the Ride                                Hurt          Parov Stelar
# 4  Enjoy the Ride                    Royksopp Forever              Röyksopp
