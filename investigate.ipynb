# %%
from main import process_itunes_tracks
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_apple, df_loaded = process_itunes_tracks()

# %%
df_apple_wip = df_apple.copy()
df_music_wip = df_loaded.copy()

# %%
# Drop columns
df_music_wip = df_music_wip.drop(columns=["Sort Name", "Sort Artist"])
# df_music_wip = df_music_wip.drop(columns=["Sort Artist"])

# Rename columns
df_music_wip = df_music_wip.rename(columns={"Name": "Sort Name", "Artist": "Sort Artist"})

df_music_wip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3080 entries, 0 to 3079
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       3080 non-null   object
#  1   Sort Artist                 3078 non-null   object
#  2   Composer                    2449 non-null   object
#  3   Encoded with                2209 non-null   object
#  4   Release Date                3008 non-null   object
#  5   Album                       3079 non-null   object
#  6   Disk                        3079 non-null   object
#  7   GenreType                   1827 non-null   object
#  8   BPM                         2370 non-null   object
#  9   Part of Compilation         3079 non-null   object
#  10  Part of Gapless Album       3011 non-null   object
#  11  Album Artist                2512 non-null   object
#  12  Genre                       1236 non-null   object
# ...

# %%
df_music_wip[(df_music_wip["Sort Artist"] != df_music_wip["Artist"]) & (~df_music_wip["Sort Artist"].isnull())]
# Out:
#           Track                  Artist  \
# 547     6 of 13       The Dandy Warhols
# 548    12 of 13       The Dandy Warhols
# 549     1 of 13       The Dandy Warhols
# 550     8 of 13       The Dandy Warhols
# 551    11 of 13       The Dandy Warhols
# 552     2 of 13       The Dandy Warhols
# 553     7 of 13       The Dandy Warhols
# 554     5 of 13       The Dandy Warhols
# 555    10 of 13       The Dandy Warhols
# 556     4 of 13       The Dandy Warhols
# 557    13 of 13       The Dandy Warhols
# 558     3 of 13       The Dandy Warhols
# 559     9 of 13       The Dandy Warhols
# 560     7 of 13       The Dandy Warhols
# 1023    4 of 14              The Panics
# 1091    3 of 12   The Chemical Brothers
# 1092    9 of 12   The Chemical Brothers
# 1093   10 of 12   The Chemical Brothers
# 1094   12 of 12   The Chemical Brothers
# 1095    5 of 12   The Chemical Brothers
# 1096    2 of 12   The Chemical Brothers
# 1097    1 of 12   The Chemical Brothers
# ...

# %%
df_apple.info()
# df_apple["iTunes Account"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Track                 484 non-null    object
#  1   Sort Name             470 non-null    object
#  2   Sort Artist           478 non-null    object
#  3   Release Date          484 non-null    object
#  4   Sort Album            460 non-null    object
#  5   Copyright             484 non-null    object
#  6   Content Rating        484 non-null    object
#  7   Media Type            484 non-null    object
#  8   Content ID            484 non-null    object
#  9   Artist ID             484 non-null    object
#  10  Playlist ID           484 non-null    object
#  11  Genre ID              484 non-null    object
#  12  Composer ID           442 non-null    object
#  13  xid                   482 non-null    object
#  14  iTunes Account        484 non-null    object
# ...

# %%
df_loaded.info()
df_loaded["iTunes Account"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3080 entries, 0 to 3079
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       3080 non-null   object
#  1   Name                        3079 non-null   object
#  2   Artist                      3078 non-null   object
#  3   Composer                    2449 non-null   object
#  4   Encoded with                2209 non-null   object
#  5   Release Date                3008 non-null   object
#  6   Album                       3079 non-null   object
#  7   Disk                        3079 non-null   object
#  8   GenreType                   1827 non-null   object
#  9   BPM                         2370 non-null   object
#  10  Part of Compilation         3079 non-null   object
#  11  Part of Gapless Album       3011 non-null   object
#  12  Album Artist                2512 non-null   object
# ...

# %%
# df_loaded.head(50)

xid = df_loaded[~df_loaded["xid"].isnull()]
xid.head(50)
# xid.info()
# Out:
#          Track                                               Name  \
# 41    12 of 20                                Back Where I Belong
# 42    14 of 20                    Written In Scars (Live In Rome)
# 43     8 of 20                                         The Hunger
# 44    10 of 20                              Wasted (feat. Lissie)
# 45     1 of 20                                         Back to Me
# 46    13 of 20                                           Catapult
# 47    17 of 20                                Home (Live In Rome)
# 48     5 of 20                                       Broken Glass
# 49    19 of 20            Jack In a Box (Alexander Brown Version)
# 50     2 of 20                                               Home
# 51     4 of 20                                        Tie Me Down
# 52     7 of 20                                   Nobody 'Cept You
# 53     3 of 20                                      Don't Mind Me
# ...

# %%
df_loaded["Name"].unique()
# Out:
# array([' Do You Know', ' Chocolate Brown', ' Every Morning', ...,
#        ' Resurrection', ' The Bitch', ' The 4th Floor'], dtype=object)
